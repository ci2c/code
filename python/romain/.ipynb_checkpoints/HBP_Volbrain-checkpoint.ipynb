# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
from selenium.webdriver import Firefox
import os,sys,datetime,random,re
from collections import OrderedDict
import csv
import itertools
import time
from shutil import copyfile
import glob

ladate=datetime.datetime.today().strftime('%Y-%m-%d')
myDict = {"romain_viard@yahoo.fr":"xIO52ts0UWm5","juliette.mitjans@yahoo.fr":"mdpvolbrain","rhumun@gmail.com":"EYyS9kx1UhWo","renaud.lopes@gmail.com":"Ci2c@chru","clement.bne@gmail.com":"ci2clille","quentinvannodmichel@gmail.com":"p53q37rst","gregkuch@msn.com":"greg2004","e_nedeva@hotmail.com":"VolbrainMdp","jbdavion@hotmail.fr":"neuro2309"}
myDictSorted=OrderedDict(sorted(myDict.items(), key=lambda t: t[0],reverse=True))
ladate=datetime.datetime.today().strftime('%Y-%m-%d')

fh = open('/NAS/dumbo/protocoles/HBP/participantsRest.tsv')
reader = csv.reader(fh, delimiter = '\t')
data = [v for v in itertools.islice(reader,0, None)]

inputFile = open('''/NAS/dumbo/protocoles/HBP/nbPat.txt''')
numPat = int(inputFile.readline())
inputFile.close()
print numPat

for eval_order in range(0,len(myDictSorted)) :
    
    print eval_order
    numPat=numPat+1
    if numPat > 123 :
        break
    
    cle = myDictSorted.items()[eval_order][0]
    valeur = myDictSorted.items()[eval_order][1]
    
    print cle
    
    options = Options()
    options.add_argument("--headless")
    driver = Firefox(firefox_options=options)
    driver.get("http://volbrain.upv.es/index.php")
    elem = driver.find_element_by_name("email")
    elem.send_keys(cle)
    elem = driver.find_element_by_name("password")
    elem.send_keys(valeur)
    elem = driver.find_element_by_name("sub")
    elem.click()   
    
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=elem.get_attribute('innerHTML')
    txt_tab_vol_brain=elem.text
    deb=0
    for m in re.finditer(" "+str(ladate)+" ",txt_tab_vol_brain):
        deb += 1
    print(deb)    
    for cpt in range(deb,10):  
        T1_filenameFS = '''/NAS/dumbo/protocoles/HBP/Volumetrie/'''+data[numPat][0]
        print T1_filenameFS
        while  ( (len(glob.glob('/NAS/dumbo/protocoles/HBP/volbrain/'+data[numPat][0]+'*')) > 0 ) or not (os.path.isfile(T1_filenameFS)) ): 
            if numPat > 123 :
                break
            numPat=numPat+1
            T1_filenameFS = '''/NAS/dumbo/protocoles/HBP/Volumetrie/'''+data[numPat][0] 
        
        if numPat > 123 :
            break
        
        sexe = data[numPat][1] 
        age = data[numPat][2] 
        time.sleep(2)
        elem = driver.find_element_by_id("pipeline1")
        elem.click()
        elem = driver.find_element_by_name("volbrain_t1_file")
        elem.send_keys(T1_filenameFS)
        elem = driver.find_element_by_name("volbrain_patientssex")
        elem.send_keys(sexe)
        elem = driver.find_element_by_name("volbrain_patientsage")
        elem.send_keys(age)
        elem = driver.find_element_by_name("button_volbrain")
        elem.click()
        #time.sleep(3)
            
        print numPat
        print cle
        print T1_filenameFS
        
        outputFile = open('''/NAS/dumbo/protocoles/HBP/nbPat.txt''','w')
        outputFile.write(str(numPat));
        outputFile.close()
        numPat=numPat+1
            
    driver.stop_client()
# Out:
# 119
# 0
# romain_viard@yahoo.fr
# 10
# 1
# rhumun@gmail.com
# 9
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-d4e6b1b09dc6> in <module>()
#      56     print(deb)
#      57     for cpt in range(deb,10):
# ---> 58         T1_filenameFS = '''/NAS/dumbo/protocoles/HBP/Volumetrie/'''+data[numPat][0]
#      59
#      60         while  ( (len(glob.glob('/NAS/dumbo/protocoles/HBP/volbrain/'+data[numPat][0]+'*')) > 0 ) or not (os.path.isfile(T1_filenameFS)) ):
#
# IndexError: list index out of range

# %%
print(myDictSorted)
len(myDictSorted)
# Out:
# OrderedDict([('romain_viard@yahoo.fr', 'xIO52ts0UWm5'), ('rhumun@gmail.com', 'EYyS9kx1UhWo'), ('renaud.lopes@gmail.com', 'Ci2c@chru'), ('quentinvannodmichel@gmail.com', 'p53q37rst'), ('juliette.mitjans@yahoo.fr', 'mdpvolbrain'), ('jbdavion@hotmail.fr', 'neuro2309'), ('gregkuch@msn.com', 'greg2004'), ('e_nedeva@hotmail.com', 'VolbrainMdp'), ('clement.bne@gmail.com', 'ci2clille')])
# 9

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
from selenium.webdriver import Firefox
import os,sys,datetime,random,re
from collections import OrderedDict
import csv
import itertools
import time
from shutil import copyfile
import urllib2

ladate="160719" #datetime.datetime.today().strftime('%Y-%m-%d')
myDict = {"romain_viard@yahoo.fr":"xIO52ts0UWm5","juliette.mitjans@yahoo.fr":"mdpvolbrain","rhumun@gmail.com":"EYyS9kx1UhWo","renaud.lopes@gmail.com":"Ci2c@chru","clement.bne@gmail.com":"ci2clille","quentinvannodmichel@gmail.com":"p53q37rst","gregkuch@msn.com":"greg2004","e_nedeva@hotmail.com":"VolbrainMdp","jbdavion@hotmail.fr":"neuro2309"}
myDictSorted=OrderedDict(sorted(myDict.items(), key=lambda t: t[0],reverse=True))

fh = open('/NAS/dumbo/protocoles/HBP/participants.tsv')
reader = csv.reader(fh, delimiter = '\t')
data = [v for v in itertools.islice(reader,0, None)]

for eval_order in range(0,len(myDictSorted)) :
    cle = myDictSorted.items()[eval_order][0]
    valeur = myDictSorted.items()[eval_order][1]
    print cle
    options = Options()
    options.add_argument("--headless")
    driver = Firefox(firefox_options=options)
    driver.get("http://volbrain.upv.es/index.php")
    elem = driver.find_element_by_name("email")
    elem.send_keys(cle)
    elem = driver.find_element_by_name("password")
    elem.send_keys(valeur)
    elem = driver.find_element_by_name("sub")
    elem.click()   
    
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=elem.get_attribute('innerHTML')
    txt_tab_vol_brain=elem.text
    #Deuxième page
    myvar="loadJobList(2)"
    driver.execute_script(myvar)
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
    txt_tab_vol_brain=txt_tab_vol_brain+elem.text

    myvar="loadJobList(3)"
    driver.execute_script(myvar)
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
    txt_tab_vol_brain=txt_tab_vol_brain+elem.text
    
    myvar="loadJobList(4)"
    driver.execute_script(myvar)
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
    txt_tab_vol_brain=txt_tab_vol_brain+elem.text
    
    myvar="loadJobList(5)"
    driver.execute_script(myvar)
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
    txt_tab_vol_brain=txt_tab_vol_brain+elem.text
    
    regex="https:\/\/files.volbrain.upv.es.{10,90}?"+str(ladate)+".{1,10}?zip"
    myIterator = re.finditer(regex,html_tab_vol_brain)
    for it in myIterator :
        mystr=html_tab_vol_brain[it.start():it.end()]
        if not os.path.isfile('''/NAS/dumbo/protocoles/HBP/volbrain/'''+mystr[30:]) :
            print(mystr)
            attempts = 0
            while attempts < 3:
                try:
                    response = urllib2.urlopen(mystr, timeout = 5)
                    content = response.read()
                    f = open('''/NAS/dumbo/protocoles/HBP/volbrain/'''+mystr[30:], 'w' )
                    f.write( content )
                    f.close() 
                    break
                except urllib2.URLError as e:
                    attempts += 1
                    print type(e)       
    driver.stop_client()       
    #driver.close()
# Out:
# romain_viard@yahoo.fr
# rhumun@gmail.com
# renaud.lopes@gmail.com
# quentinvannodmichel@gmail.com
# juliette.mitjans@yahoo.fr
# jbdavion@hotmail.fr
# gregkuch@msn.com
# e_nedeva@hotmail.com
# clement.bne@gmail.com
