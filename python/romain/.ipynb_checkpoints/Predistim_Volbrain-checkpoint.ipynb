# %% [markdown]
# nb cartes R2* = 361 #ls R2/*/R2_nonlin_atlas.nii.gz | wc -l
# nb cartes QSM =

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
from selenium.webdriver import Firefox
from selenium.webdriver.support.ui import WebDriverWait
import os,sys,datetime,random,re
from collections import OrderedDict
import csv
import itertools
import time
from shutil import copyfile
import glob
import pandas as pd 
import urllib3
import requests
from clint.textui import progress

# %%
#STUDY_PATH='''D:\\LINUX\\Predistim\\data\\'''
STUDY_PATH='/NAS/deathrow/protocoles/predistim'
myDict = {"romain.viard@chru-lille.fr":"romainviardchru","a.viard@outlook.fr":"aviardoutlook","j.viard@outlook.fr":"jviardoutlook","romain_viard@yahoo.fr":"xIO52ts0UWm5","juliette.mitjans@yahoo.fr":"mdpvolbrain","rhumun@gmail.com":"EYyS9kx1UhWo","renaud.lopes@gmail.com":"Ci2c@chru","clement.bne@gmail.com":"ci2clille","quentinvannodmichel@gmail.com":"p53q37rst","gregkuch@msn.com":"greg2004","e_nedeva@hotmail.com":"VolbrainMdp","jbdavion@hotmail.fr":"neuro2309"}
myDictSorted=OrderedDict(sorted(myDict.items(), key=lambda t: t[0],reverse=True))

# %%
ladate=datetime.datetime.today().strftime('%Y-%m-%d')

fh = open(STUDY_PATH+'listePatTMP.tsv')
reader = csv.reader(fh, delimiter = '\t')
data = [v for v in itertools.islice(reader,0, None)]

inputFile = open(STUDY_PATH+'nbPat.txt')
numPat = int(inputFile.readline())
inputFile.close()
print(numPat)

#for eval_order in range(0,len(myDictSorted)) :
for cle,valeur in myDictSorted.items():
    
    if numPat > 1 :
        break
    cle="rhumun@gmail.com"
    valeur="EYyS9kx1UhWo"
    print(cle)
    print(numPat)
    
    options = Options()
    options.add_argument("--headless")
    driver = Firefox(firefox_options=options)
    driver.get("http://volbrain.upv.es/index.php")
    elem = driver.find_element_by_name("email")
    elem.send_keys(cle)
    elem = driver.find_element_by_name("password")
    elem.send_keys(valeur)
    elem = driver.find_element_by_name("sub")
    elem.click()   
    
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=elem.get_attribute('innerHTML')
    txt_tab_vol_brain=elem.text
    deb=0
    for m in re.finditer(" "+str(ladate)+" ",txt_tab_vol_brain):
        deb += 1
    print(deb)    
    print(data[numPat][0])
    for cpt in range(deb,10): 
        if numPat < 1 :           
            PT_PATH=STUDY_PATH+'''data\\2020-04-02\\'''+data[numPat][0][:2]+'''\\'''+data[numPat][0]+'''\\M00\\'''
            T1_filenameFS=PT_PATH+'''mri_3dt1_t1_geo_nifti.nii.gz'''

            #if not (os.path.isfile(T1_filenameFS)) :
            #    T1_filenameFS = '''/NAS/deathrow/protocoles/predistim/2018-07-30_t1_segmentations/'''+data[numPat][0][:2]+'''/'''+data[numPat][0]+'''/M00/mri_3dt1_t1_geo_nifti.nii.gz'''

            if not (os.path.isfile(T1_filenameFS)) :
                T1_filenameFS = PT_PATH+'''mri_3dt1_t1_nifti.nii.gz'''

            print(T1_filenameFS)
            while  ( (len(glob.glob(STUDY_PATH+'''data\\volbrain\\'''+data[numPat][0]+'*')) > 0 ) or not (os.path.isfile(T1_filenameFS)) ): 
                if numPat > 1 :
                    break
                numPat=numPat+1
                print(numPat)
                PT_PATH=STUDY_PATH+'''data\\2020-04-02\\'''+data[numPat][0][:2]+'''\\'''+data[numPat][0]+'''\\M00\\'''
                T1_filenameFS=PT_PATH+'''mri_3dt1_t1_geo_nifti.nii.gz'''

                if not (os.path.isfile(T1_filenameFS)) :
                    T1_filenameFS = PT_PATH+'''mri_3dt1_t1_nifti.nii.gz'''

            if numPat > 1 :
                break

            T1_filenameR = PT_PATH+data[numPat][0]+'''test.nii.gz'''     
            copyfile(T1_filenameFS,T1_filenameR)            
            age = data[numPat][2] 
            sexe = data[numPat][1] 
            time.sleep(2)
            elem = driver.find_element_by_id("pipeline1")
            elem.click()
            elem = driver.find_element_by_name("volbrain_t1_file")
            elem.send_keys(T1_filenameR)
            elem = driver.find_element_by_name("volbrain_patientssex")
            elem.send_keys(sexe)
            elem = driver.find_element_by_name("volbrain_patientsage")
            elem.send_keys(age)
            elem = driver.find_element_by_name("button_volbrain")
            elem.click()
            time.sleep(120)

            print(numPat)
            print(cle)
            print(T1_filenameFS)
            print(T1_filenameR)

            outputFile = open(STUDY_PATH+'nbPat.txt','w')
            outputFile.write(str(numPat));
            outputFile.close()
            numPat=numPat+1
            
    driver.stop_client()
# Out:
# 0
# rhumun@gmail.com
# 0
# C:\Users\romain\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: DeprecationWarning: use options instead of firefox_options
# 0
# 01001SR
# D:\LINUX\Predistim\data\2020-04-02\01\01001SR\M00\mri_3dt1_t1_nifti.nii.gz
# 0
# rhumun@gmail.com
# D:\LINUX\Predistim\data\2020-04-02\01\01001SR\M00\mri_3dt1_t1_nifti.nii.gz
# D:\LINUX\Predistim\data\2020-04-02\01\01001SR\M00\01001SRtest.nii.gz
# rhumun@gmail.com
# 1
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-b478352eb177> in <module>
#      56         deb += 1
#      57     print(deb)
# ---> 58     print(data[numPat][0])
#      59     for cpt in range(deb,10):
#      60         if numPat < 1 :
#
# IndexError: list index out of range

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
from selenium.webdriver import Firefox
import os,sys,datetime,random,re
from collections import OrderedDict
import csv
import itertools
import time
from shutil import copyfile
import urllib2

ladate=datetime.datetime.today().strftime('%Y-%m-%d') #"310719" 
myDict = {"romain_viard@yahoo.fr":"xIO52ts0UWm5","juliette.mitjans@yahoo.fr":"mdpvolbrain","rhumun@gmail.com":"EYyS9kx1UhWo","renaud.lopes@gmail.com":"Ci2c@chru","clement.bne@gmail.com":"ci2clille","quentinvannodmichel@gmail.com":"p53q37rst","gregkuch@msn.com":"greg2004","e_nedeva@hotmail.com":"VolbrainMdp","jbdavion@hotmail.fr":"neuro2309"}
myDictSorted=OrderedDict(sorted(myDict.items(), key=lambda t: t[0],reverse=True))

#fh = open('/NAS/deathrow/protocoles/predistim/listePat.tsv')
#reader = csv.reader(fh, delimiter = '\t')
#data = [v for v in itertools.islice(reader,0, None)]

#for eval_order in range(0,len(myDictSorted)) :
for cle,valeur in myDictSorted.items():

    #cle = myDictSorted.items()[eval_order][0]
    #valeur = myDictSorted.items()[eval_order][1]
    #print(cle)
    options = Options()
    options.add_argument("--headless")
    driver = Firefox(firefox_options=options)
    driver.get("http://volbrain.upv.es/index.php")
    elem = driver.find_element_by_name("email")
    elem.send_keys(cle)
    elem = driver.find_element_by_name("password")
    elem.send_keys(valeur)
    elem = driver.find_element_by_name("sub")
    elem.click()   
    
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=elem.get_attribute('innerHTML')
    txt_tab_vol_brain=elem.text
    #Deuxième page
    myvar="loadJobList(2)"
    driver.execute_script(myvar)
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
    txt_tab_vol_brain=txt_tab_vol_brain+elem.text

    myvar="loadJobList(3)"
    driver.execute_script(myvar)
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
    txt_tab_vol_brain=txt_tab_vol_brain+elem.text
    
    myvar="loadJobList(4)"
    driver.execute_script(myvar)
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
    txt_tab_vol_brain=txt_tab_vol_brain+elem.text
    
    myvar="loadJobList(5)"
    driver.execute_script(myvar)
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
    txt_tab_vol_brain=txt_tab_vol_brain+elem.text
    
    regex="https:\/\/files.volbrain.upv.es.{1,50}?"+str(ladate)+".{1,10}?zip"
    myIterator = re.finditer(regex,html_tab_vol_brain)
    for it in myIterator :
        mystr=html_tab_vol_brain[it.start():it.end()]
        if not os.path.isfile(STUDY_PATH+'''data\\volbrain\\'''+mystr[30:]) :
            print(mystr)
            attempts = 0
            while attempts < 3:
                try:
                    response = urllib2.urlopen(mystr, timeout = 5)
                    content = response.read()
                    f = open(STUDY_PATH+'''data\\volbrain\\'''+mystr[30:], 'w' )
                    f.write( content )
                    f.close() 
                    break
                except urllib2.URLError as e:
                    attempts += 1
                    print(type(e))       
    driver.stop_client()       
    #driver.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-378f81fe8c62> in <module>
#       9 import time
#      10 from shutil import copyfile
# ---> 11 import urllib2
#      12
#      13 ladate=datetime.datetime.today().strftime('%Y-%m-%d') #"310719"
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
def getProceedTask(idvb,pwd):
    ladate=datetime.datetime.today().strftime('%Y-%m-%d')
    print(ladate)
    ladate="0420"
    print(ladate)
    options = Options()
    options.headless = True
    driver = Firefox(options=options)
    driver.implicitly_wait(15)
    #WebDriverWait(driver, timeout=5).until(document_initialised)
    driver.get("http://volbrain.upv.es/index.php")
    elem = driver.find_element_by_name("email")
    elem.send_keys(idvb)
    elem = driver.find_element_by_name("password")
    elem.send_keys(pwd)
    elem = driver.find_element_by_name("sub")
    elem.click()   
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=elem.get_attribute('innerHTML')
    txt_tab_vol_brain=elem.text
    
    for n in range(2,6,1):
        driver.execute_script("loadJobList("+str(n)+")")
        elem = driver.find_element_by_name("job_list")
        html_tab_vol_brain=html_tab_vol_brain+elem.get_attribute('innerHTML')
        txt_tab_vol_brain=txt_tab_vol_brain+elem.text

    #print(html_tab_vol_brain)
    
    regex="https:\/\/files.volbrain.upv.es.{1,50}?"+str(ladate)+".{1,10}?zip"
   
    #for m in re.finditer(" "+str(ladate)+" ",txt_tab_vol_brain):
    #    deb -= 1
        
    for it in re.finditer(regex,html_tab_vol_brain) :
        mystr=html_tab_vol_brain[it.start():it.end()]        
        filepath=os.path.join(STUDY_PATH,'volbrain',mystr[30:])
        if not os.path.isfile(filepath) :
            print(mystr)
            attempts = 0
            while attempts < 3:
                try:
                    #response = urllib3.urlopen(mystr, timeout = 5)
                    #content = response.read()
                    
                    #http = urllib3.PoolManager(timeout=10.0)
                    #r = http.request('GET', mystr, retries=10)                   
                    
                    #f = open(filepath, 'w' )
                    #f.write( "coucou" )
                    #f.close() 
                    
                    r = requests.get(mystr, stream=True)
                    with open(filepath, 'wb') as f:
                        total_length = int(r.headers.get('content-length'))
                        for chunk in progress.bar(r.iter_content(chunk_size=1024), expected_size=(total_length/1024) + 1): 
                            if chunk:
                                f.write(chunk)
                                f.flush()                                      
                    
                    #!wget mystr
                    
                    break
                except urllib3.exceptions.NewConnectionError: #urllib3.URLError as e:
                    attempts += 1
                    print(type(e)) 
        
        if os.path.isfile(os.path.join(STUDY_PATH,'volbrain',mystr[30:44])): #(mystr[30:].startswith('1') | mystr[30:].startswith('0')) :
            #print(os.path.join(STUDY_PATH,'volbrain',mystr[30:44]))
            os.remove(os.path.join(STUDY_PATH,'volbrain',mystr[30:44])) 
        
    driver.stop_client()       
    driver.close()

# %%
def document_initialised(driver):
    return driver.execute_script("return initialised")

# %%
def getAgeAndSexe(ptID):    
    fh = open(os.path.join(STUDY_PATH,'DemographicData20200406.csv'))
    reader = csv.reader(fh, delimiter = ';')

    for ligne in reader:
        if ligne[0]==ptID:
            break

    return ligne[1], ligne[2]
#df = pd.read_csv(file_name,sep = ';')

# %%
def getCQT1AndMultiTE(ptID):
    fh = open(os.path.join(STUDY_PATH,'CQData20200406.csv'))
    reader = csv.reader(fh, delimiter = ';')

    for ligne in reader:
        if ligne[0]==ptID:
            break

    return ligne[1], ligne[2]
#df = pd.read_csv(file_name,sep = ';')

# %%
def get3DT1File(ptID):
    file_3DT1=''
    DIR=os.path.join(STUDY_PATH,'2020-04-02',ptID[0:2],ptID,'M00')
    if os.path.exists(os.path.join(DIR,'mri_3dt1_t1_geo_nifti.nii.gz')) :
        file_3DT1=os.path.join(DIR,'mri_3dt1_t1_geo_nifti.nii.gz')
    elif os.path.exists(os.path.join(DIR,'mri_3dt1_t1_nobias_geo_nifti.nii.gz')) :
        file_3DT1=os.path.join(DIR,'mri_3dt1_t1_nobias_geo_nifti.nii.gz')
    elif os.path.exists(os.path.join(DIR,'mri_3dt1_t1_nifti.nii.gz')) :
        file_3DT1=os.path.join(DIR,'mri_3dt1_t1_nifti.nii.gz')
    elif os.path.exists(os.path.join(DIR,'mri_3dt1_t1_nobias_nifti.nii.gz')) :
        file_3DT1=os.path.join(DIR,'mri_3dt1_t1_nobias_nifti.nii.gz')
    else :
        file_3DT1=''
        
    return file_3DT1
#df = pd.read_csv(file_name,sep = ';')

# %%
def getMultiTEFile(ptID):
    file_3DT1=''
    DIR=os.path.join(STUDY_PATH,'2020-04-02',ptID[0:2],ptID,'M00')
    if os.path.exists(os.path.join(DIR,'mri_3dmultigre_multigre_geo_nifti.nii.gz')) :
        file_3DT1=os.path.join(DIR,'mri_3dmultigre_multigre_geo_nifti.nii.gz')
    elif os.path.exists(os.path.join(DIR,'mri_3dmultigre_multigre_nobias_geo_nifti.nii.gz')) :
        file_3DT1=os.path.join(DIR,'mri_3dmultigre_multigre_nobias_geo_nifti.nii.gz')
    elif os.path.exists(os.path.join(DIR,'mri_3dmultigre_multigre_nifti.nii.gz')) :
        file_3DT1=os.path.join(DIR,'mri_3dmultigre_multigre_nifti.nii.gz')
    elif os.path.exists(os.path.join(DIR,'mri_3dmultigre_multigre_nobias_nifti.nii.gz')) :
        file_3DT1=os.path.join(DIR,'mri_3dmultigre_multigre_nobias_nifti.nii.gz')
    else :
        file_3DT1=''
        
    return file_3DT1
#df = pd.read_csv(file_name,sep = ';

# %%
def getNbAvailable(idvb,pwd):
    ladate=datetime.datetime.today().strftime('%Y-%m-%d')
    options = Options()
    options.headless = True
    driver = Firefox(options=options)
    driver.implicitly_wait(15)
    #WebDriverWait(driver, timeout=5).until(document_initialised)
    driver.get("http://volbrain.upv.es/index.php")
    elem = driver.find_element_by_name("email")
    elem.send_keys(idvb)
    elem = driver.find_element_by_name("password")
    elem.send_keys(pwd)
    elem = driver.find_element_by_name("sub")
    elem.click()   
    elem = driver.find_element_by_name("job_list")
    html_tab_vol_brain=elem.get_attribute('innerHTML')
    txt_tab_vol_brain=elem.text
    driver.stop_client()       
    driver.close()
    deb=10
    for m in re.finditer(" "+str(ladate)+" ",txt_tab_vol_brain):
        deb -= 1
    return deb

# %%
def sendFileOnVB(file,age,sexe,idvb,pwd):
    options = Options()
    options.headless = True
    driver = Firefox(options=options)
    driver.implicitly_wait(15)
   #WebDriverWait(driver, timeout=5).until(document_initialised)
    driver.get("https://volbrain.upv.es/index.php")
    #print("Web site reached")
    elem = driver.find_element_by_name("email")
    elem.send_keys(idvb)
    elem = driver.find_element_by_name("password")
    elem.send_keys(pwd)
    #print("Connected")
    elem = driver.find_element_by_name("sub")
    elem.click()
    elem = driver.find_element_by_id("pipeline1")
    elem.click()
    #print("Pipeline1 Ok")
    elem = driver.find_element_by_name("volbrain_t1_file")
    elem.send_keys(file)
    elem = driver.find_element_by_name("volbrain_patientssex")
    elem.send_keys(sexe)
    elem = driver.find_element_by_name("volbrain_patientsage")
    elem.send_keys(age)
    elem = driver.find_element_by_name("button_volbrain")
    elem.click()
    #print("Data sent")
    driver.stop_client()       
    driver.close()

# %% [markdown]
# # Envoi des 3DT1 sur Volbrain

# %%
dir_names=glob.glob(os.path.join(STUDY_PATH,'2020-04-02','*','*'))
for dir_name in dir_names :
    SUBJID=os.path.split(dir_name)[1]
    CQT1,CQTE=getCQT1AndMultiTE(SUBJID)
    if True : #(SUBJID.startswith('01') | SUBJID.startswith('17') | SUBJID.startswith('19')):
        if ((int(CQT1)>2) & (int(CQTE)>2)) :
            files_namesDone=glob.glob(os.path.join(STUDY_PATH,'volbrain','*'+SUBJID+'*.zip'))
            files_namesRunning=glob.glob(os.path.join(STUDY_PATH,'volbrain',SUBJID+'.nii.gz'))
            if not((len(files_namesDone)>1) | (len(files_namesRunning)==1)) :
                file_3DT1=get3DT1File(SUBJID)
                file_multiTE=getMultiTEFile(SUBJID)  
                age,sexe=getAgeAndSexe(SUBJID[0:-2])        
                print(SUBJID+' '+CQT1+' '+file_3DT1+' '+CQTE+' '+file_multiTE+' '+age+' '+sexe)
                for cle,valeur in myDictSorted.items():
                    dispo=getNbAvailable(cle,valeur)
                    if dispo > 0 :
                        T1_filename = os.path.join(STUDY_PATH,'volbrain',SUBJID+'.nii.gz')
                        print(T1_filename)
                        copyfile(file_3DT1,T1_filename)                          
                        sendFileOnVB(T1_filename,age,sexe,cle,valeur)                                            
                        print('ok on : '+ cle)
                        break

# %% [markdown]
# # Recupération des zip sur VolBrain

# %%
for cle,valeur in myDictSorted.items():
    getProceedTask(cle,valeur)
# Out:
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420
# 2020-05-04
# 0420

# %% [markdown]
# # carte R2 * et recalage sur MNI

# %%
dir_names=glob.glob(os.path.join(STUDY_PATH,'2020-04-02','*','*'))
for dir_name in dir_names :
    SUBJID=os.path.split(dir_name)[1]
    CQT1,CQTE=getCQT1AndMultiTE(SUBJID)
    if ((int(CQT1)>2) & (int(CQTE)>2)) :
        file_3DT1=get3DT1File(SUBJID)        
        file_multiTE=getMultiTEFile(SUBJID)  
        if not os.path.exists(os.path.join(STUDY_PATH,'R2',SUBJID,'R2_nonlin_atlas.nii.gz')) :
            cmd="qbatch -q three_job_q -oe "+os.path.join(STUDY_PATH,'code','log')+" -N R2_"+ SUBJID +" bash "+ os.path.join(STUDY_PATH,'code')+"/R2_analysis.sh "+SUBJID+" "+file_multiTE+" "+file_3DT1
            print(cmd)
# Out:
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_07017LA bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 07017LA  /NAS/deathrow/protocoles/predistim/2020-04-02/07/07017LA/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_07031DA bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 07031DA  /NAS/deathrow/protocoles/predistim/2020-04-02/07/07031DA/M00/mri_3dt1_t1_nobias_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_08020VJ bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 08020VJ  /NAS/deathrow/protocoles/predistim/2020-04-02/08/08020VJ/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_08025HV bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 08025HV  /NAS/deathrow/protocoles/predistim/2020-04-02/08/08025HV/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_08029JD bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 08029JD  /NAS/deathrow/protocoles/predistim/2020-04-02/08/08029JD/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_08037CG bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 08037CG  /NAS/deathrow/protocoles/predistim/2020-04-02/08/08037CG/M00/mri_3dt1_t1_nobias_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_08038FS bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 08038FS  /NAS/deathrow/protocoles/predistim/2020-04-02/08/08038FS/M00/mri_3dt1_t1_nobias_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_08039PD bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 08039PD  /NAS/deathrow/protocoles/predistim/2020-04-02/08/08039PD/M00/mri_3dt1_t1_nobias_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_08040AC bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 08040AC  /NAS/deathrow/protocoles/predistim/2020-04-02/08/08040AC/M00/mri_3dt1_t1_nobias_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_08042LS bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 08042LS  /NAS/deathrow/protocoles/predistim/2020-04-02/08/08042LS/M00/mri_3dt1_t1_nobias_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_09013DS bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 09013DS  /NAS/deathrow/protocoles/predistim/2020-04-02/09/09013DS/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_14006AJ bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 14006AJ  /NAS/deathrow/protocoles/predistim/2020-04-02/14/14006AJ/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_14008MC bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 14008MC  /NAS/deathrow/protocoles/predistim/2020-04-02/14/14008MC/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_14009DP bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 14009DP  /NAS/deathrow/protocoles/predistim/2020-04-02/14/14009DP/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_14011GM bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 14011GM  /NAS/deathrow/protocoles/predistim/2020-04-02/14/14011GM/M00/mri_3dt1_t1_geo_nifti.nii.gz
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N R2_17044DJ bash /NAS/deathrow/protocoles/predistim/code/R2_analysis.sh 17044DJ  /NAS/deathrow/protocoles/predistim/2020-04-02/17/17044DJ/M00/mri_3dt1_t1_geo_nifti.nii.gz

# %% [markdown]
# # Unzip dicomfiles for QSM processing

# %%
from zipfile import ZipFile
import tarfile

dir_names=glob.glob(os.path.join(STUDY_PATH,'2020-04-02','*','*'))
for dir_name in dir_names :
    SUBJID=os.path.split(dir_name)[1]
    if (SUBJID.startswith('01') | SUBJID.startswith('17') | SUBJID.startswith('19')):
        CQT1,CQTE=getCQT1AndMultiTE(SUBJID)
        if ((int(CQT1)>2) & (int(CQTE)>2)) :        
            if not os.path.exists(os.path.join(STUDY_PATH,'QSM',SUBJID,'QSM_lin_atlas.nii.gz')) :            
                file_3DT1=get3DT1File(SUBJID)        
                file_multiTE=getMultiTEFile(SUBJID)  
                files_im=file_multiTE.replace('nifti.nii.gz','dicom.tar.gz').replace('mri_3dmultigre_multigre','mri_3dmultigre_multigreim').replace('_geo_','_')
                files_re=file_multiTE.replace('nifti.nii.gz','dicom.tar.gz').replace('mri_3dmultigre_multigre','mri_3dmultigre_multigrere').replace('_geo_','_')
                if not (os.path.exists(os.path.join(STUDY_PATH,'QSM',SUBJID,'dicom_v1'))):
                    if (os.path.exists(os.path.join(STUDY_PATH,'QSM',SUBJID,'dicom'))):
                        os.rename(os.path.join(STUDY_PATH,'QSM',SUBJID,'dicom'),os.path.join(STUDY_PATH,'QSM',SUBJID,'dicom_v1'))                

                    if (os.path.exists(files_im) & os.path.exists(files_re)):
                        print(SUBJID)
                        tf = tarfile.open(files_im)
                        #print(files_im)
                        tf.extractall(path=os.path.join(STUDY_PATH,'QSM',SUBJID,'dicom'))
                        tf = tarfile.open(files_re)
                        #print(files_re)
                        tf.extractall(path=os.path.join(STUDY_PATH,'QSM',SUBJID,'dicom'))  
                    else :
                        files_dicom=file_multiTE.replace('nifti.nii.gz','dicom.tar.gz')
                        if (os.path.exists(files_dicom)):
                            print(SUBJID)
                            tf = tarfile.open(files_dicom)
                            #print(files_dicom)
                            tf.extractall(path=os.path.join(STUDY_PATH,'QSM',SUBJID,'dicom'))                    
                        else :
                            print(SUBJID + " NOK : " + file_multiTE)
# Out:
# 17044DJ NOK :
# 17051AV
# 17052BP
# 17053KC
# 17054BL
# 17055DA
# 17057CF
# 17060JR
# 17061BC
# 17062GD
# 17065CM
# 17066DE
# 17068MJ
# 17069BB
# 17070MJ
# 17071PM
# 17072PF
# 17073GP
# 17076CJ
# 17077BS
# 17078ZH
# 17079DM
# 17080RC
# 19011LA
# 19012GD
# 19013PA
# 19014GC
# 19015SO

# %% [markdown]
# # QSM et application du recalage sur MNI

# %%
dir_names=glob.glob(os.path.join(STUDY_PATH,'2020-04-02','*','*'))
for dir_name in dir_names :
    SUBJID=os.path.split(dir_name)[1]
    CQT1,CQTE=getCQT1AndMultiTE(SUBJID)
    if (SUBJID.startswith('01') | SUBJID.startswith('17') | SUBJID.startswith('19')):
        if ((int(CQT1)>2) & (int(CQTE)>2)) :
            if not os.path.exists(os.path.join(STUDY_PATH,'QSM',SUBJID,'QSM_nonlin_atlas.nii.gz')) :
                cmd="qbatch -q three_job_q -oe "+os.path.join(STUDY_PATH,'code','log')+" -N QSM_"+ SUBJID +" bash "+ os.path.join(STUDY_PATH,'code')+"/computeQSM.sh "+SUBJID
                print(cmd)
# Out:
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01011BB bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01011BB
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01014DE bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01014DE
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01015HC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01015HC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01016BP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01016BP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01017TA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01017TA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01018MT bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01018MT
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01019LJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01019LJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01020VM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01020VM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01023CF bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01023CF
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01024FC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01024FC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01025RE bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01025RE
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01026AF bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01026AF
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01027TM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01027TM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01028SA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01028SA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01029LL bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01029LL
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01030DM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01030DM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01031FB bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01031FB
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01034UG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01034UG
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01037DA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01037DA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01040LC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01040LC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01044SD bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01044SD
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01046AA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01046AA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01048LJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01048LJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01050ME bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01050ME
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01059MV bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01059MV
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01060PC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01060PC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_01061CD bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 01061CD
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17023GY bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17023GY
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17003GM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17003GM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17006LN bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17006LN
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17008BP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17008BP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17009DL bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17009DL
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17010BG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17010BG
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17011MG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17011MG
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17013MP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17013MP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17014PP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17014PP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17016VB bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17016VB
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17017FH bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17017FH
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17018GJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17018GJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17019JF bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17019JF
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17020LP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17020LP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17021BM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17021BM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17022PG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17022PG
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17024BR bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17024BR
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17026AM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17026AM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17027JA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17027JA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17028PT bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17028PT
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17029NM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17029NM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17030GR bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17030GR
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17033GR bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17033GR
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17034BM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17034BM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17035PD bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17035PD
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17040MD bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17040MD
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17041FJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17041FJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17043MG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17043MG
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17044DJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17044DJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17046CE bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17046CE
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17047FG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17047FG
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17049RG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17049RG
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17050PD bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17050PD
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17051AV bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17051AV
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17052BP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17052BP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17053KC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17053KC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17054BL bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17054BL
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17055DA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17055DA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17057CF bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17057CF
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17060JR bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17060JR
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17061BC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17061BC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17062GD bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17062GD
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17065CM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17065CM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17066DE bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17066DE
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17068MJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17068MJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17069BB bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17069BB
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17070MJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17070MJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17071PM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17071PM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17072PF bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17072PF
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17073GP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17073GP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17075GR bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17075GR
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17076CJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17076CJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17077BS bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17077BS
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17078ZH bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17078ZH
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17079DM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17079DM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_17080RC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 17080RC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19022GN bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19022GN
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19001HF bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19001HF
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19003LJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19003LJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19005RF bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19005RF
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19008GG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19008GG
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19009AP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19009AP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19010DJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19010DJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19011LA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19011LA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19012GD bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19012GD
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19013PA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19013PA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19014GC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19014GC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19015SO bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19015SO
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19016MC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19016MC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19018GJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19018GJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19019LB bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19019LB
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19021MH bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19021MH
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19023GM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19023GM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19025BO bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19025BO
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19026MY bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19026MY
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19028LC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19028LC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19029SF bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19029SF
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19030RJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19030RJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19032PJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19032PJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19034MP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19034MP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19037GP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19037GP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19040PP bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19040PP
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19041CS bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19041CS
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19045LE bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19045LE
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19047MA bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19047MA
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19048EC bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19048EC
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19049DM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19049DM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19050PM bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19050PM
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19051FJ bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19051FJ
# qbatch -q three_job_q -oe /NAS/deathrow/protocoles/predistim/code/log -N QSM_19052BG bash /NAS/deathrow/protocoles/predistim/code/computeQSM.sh 19052BG

# %% [markdown]
# # Affiche les patients n'ayant pas le rescale slope/intercept dans l'entet DICOM

# %%
dir_names=glob.glob(os.path.join(STUDY_PATH,'2020-04-02','*','*'))
for dir_name in dir_names :
    SUBJID=os.path.split(dir_name)[1]
    CQT1,CQTE=getCQT1AndMultiTE(SUBJID)
    if (SUBJID.startswith('01') | SUBJID.startswith('17') | SUBJID.startswith('19')):
        if ((int(CQT1)>2) & (int(CQTE)>2)) :
            dir_files=glob.glob(os.path.join(STUDY_PATH,'QSM',SUBJID,'dicom','*'))
            for dir_file in dir_files :
                res=! dcmdump +P "0040,9224" $dir_file
                if len(res)==0 :
                    print(SUBJID)
                break
# Out:
# 01015HC
# 01024FC
# 17019JF
# 17035PD
# 17040MD
# 17051AV
# 17052BP
# 17053KC
# 17054BL
# 17055DA
# 17057CF
# 17060JR
# 17061BC
# 17062GD
# 17065CM
# 17066DE
# 17068MJ
# 17069BB
# 17070MJ
# 17071PM
# 17072PF
# 17073GP
# 17075GR
# 17076CJ
# 17077BS
# 17078ZH
# 17079DM
# 17080RC
# 19011LA
# 19012GD
# 19013PA
# 19014GC
# 19015SO
